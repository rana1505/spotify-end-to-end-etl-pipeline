# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credenditals_manager = SpotifyClientCredentials(client_id="c8c09d3214cc47078e1e0b08cbca25ed", client_secret="91837ba9b5d543e59aa1e9cf34fb328b")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credenditals_manager)

# %%
playlists = sp.user_playlists('spotify')
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_URI = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_URI)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_url = row['track']['album']['external_urls']['spotify']
    album_total_tracks = row['track']['album']['total_tracks']
    album_element = {'album_id': album_id, 'name': album_name, 'release_date':album_release_date, 'url': album_url, 'total_tracks': album_total_tracks}
    
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N',
#   'total_tracks': 1},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n',
#   'total_tracks': 10},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH',
#   'total_tracks': 12},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr',
#   'total_tracks': 7},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4',
#   'total_tracks': 1},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist': '7GlBOeep6PqTfFi59PTUUN',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name': song_name, 'duration_ms': song_duration, 'url': song_url, 'ppopularity': song_popularity, 'song_added': song_added,
                    'album_id': album_id, 'artist_id': artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'ppopularity': 99,
#   'song_added': '2024-09-16T12:45:41Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'ppopularity': 100,
#   'song_added': '2024-09-16T12:45:41Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '5G2f63n7IPVPPjfNIGih7Q',
#   'song_name': 'Taste',
#   'duration_ms': 157279,
#   'url': 'https://open.spotify.com/track/5G2f63n7IPVPPjfNIGih7Q',
#   'ppopularity': 95,
#   'song_added': '2024-09-16T12:45:41Z',
#   'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)

# %%
import pandas as pd
import numpy as np

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
# 1   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 2   3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 3   15XcLhiVMlSOipUddTNDnr                                               MUSE
# 4   5quMTd5zeI9yW5UDua8wS4                                           Espresso
# 5   1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 6   5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 7   5bBaoign62r1i7OV8w7mi9                               Please Please Please
# 8   6W0Gabv5f3ugnckc6YgfJQ                              The Emptiness Machine
# 9   168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 10  3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   url           50 non-null     object
#  4   total_tracks  50 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist'])

# %%
songs_df = pd.DataFrame.from_dict(song_list)

# %%
songs_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile       251667
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
# 2  5G2f63n7IPVPPjfNIGih7Q               Taste       157279
# 3  7tI8dRuH2Yc6RuoTjxo4dU                 Who       170887
# 4  2qSkIjg1o9h3YT9RAgYN75            Espresso       175459
#
#                                                  url  ppopularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...           99
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          100
# 2  https://open.spotify.com/track/5G2f63n7IPVPPjf...           95
# 3  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...           94
# 4  https://open.spotify.com/track/2qSkIjg1o9h3YT9...           97
#
#                  song_added                album_id               artist_id
# 0 2024-09-16 12:45:41+00:00  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# ...

# %%
artist_df.head()
# Out:
#                    artist        artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 4  1oSPZhvZMIrWW5I41kPkkY              Jimin
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 4  https://api.spotify.com/v1/artists/1oSPZhvZMIr...

# %%
album_df.head()
# Out:
#                  album_id                  name release_date  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17
# 2  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23
# 3  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19
# 4  5quMTd5zeI9yW5UDua8wS4              Espresso   2024-04-12
#
#                                                  url  total_tracks
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...             1
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...            10
# 2  https://open.spotify.com/album/3iPSVi54hsacKKl...            12
# 3  https://open.spotify.com/album/15XcLhiVMlSOipU...             7
# 4  https://open.spotify.com/album/5quMTd5zeI9yW5U...             1

# %%
songs_df['song_added'] = pd.to_datetime(songs_df['song_added'])

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\debar\AppData\Local\Temp\ipykernel_25496\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      47 non-null     object
#  1   name          47 non-null     object
#  2   release_date  47 non-null     datetime64[ns]
#  3   url           47 non-null     object
#  4   total_tracks  47 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB
